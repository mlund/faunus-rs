# %%
import numpy as np
import matplotlib.pyplot as plt

# Optional: make plots look a bit nicer
plt.style.use('seaborn-v0_8')

step, energy = np.loadtxt("energy.dat", unpack=True, usecols = [0,2])

# %%
plt.plot(step, energy)
